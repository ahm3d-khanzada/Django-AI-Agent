# %%
import django_jupyter
django_jupyter.init()
# Out:
# Notebook dir : D:\Django-AI-Agent\src\notebook
# Django root  : D:\Django-AI-Agent\src
# Django ready in Jupyter

# %%
from ai.tools import list_documents , get_document

# %%
config = {
    "user_id": 2,
}

# %%
list_documents.invoke(None , config)
# Out:
# []

# %%
get_document.invoke({"document_id": 8},config)
# Out:
# {'error': 'Document not found'}

# %%
from directories.models import Directory

Directory.objects.all().values("id", "title", "active", "owner_id")
# Out:
# <QuerySet [{'id': 4, 'title': 'Ahmed', 'active': True, 'owner_id': 1}, {'id': 8, 'title': 'Hello World', 'active': True, 'owner_id': 7}]>
