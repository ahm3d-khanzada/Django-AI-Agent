# %%
import django_jupyter
django_jupyter.init()
# Out:
# Notebook dir : D:\Django-AI-Agent\src\notebook
# Django root  : D:\Django-AI-Agent\src
# Django ready in Jupyter

# %%
from ai.agents import get_agent
from langgraph.checkpoint.memory import InMemorySaver
import uuid

# %%
checkpointer = InMemorySaver()

# %%
agent = get_agent(
    model="gpt-4o-mini",
    checkpointer=checkpointer,
)

# %%
config = {
    "configurable": {
        "user_id": 7,
        "thread_id": str(uuid.uuid4())
    }
}

# %%
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Update the titlle too make it Stanger thing V"
            }
        ]
    },
    config=config,
)

# %%
from langchain_core.messages import AIMessage

final_answer = None

for msg in response["messages"]:
    if isinstance(msg, AIMessage) and msg.content:
        final_answer = msg.content

print(final_answer)
# Out:
# The title of the document has been successfully updated to "Stranger Thing V." The current content is:
#
# "by your own you about it. In Season 5, Bill gains new powers that significantly impact the storyline."
