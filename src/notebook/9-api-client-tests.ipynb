# %%
import django_jupyter
django_jupyter.init()
# Out:
# Notebook dir : D:\Django-AI-Agent\src\notebook
# Django root  : D:\Django-AI-Agent\src
# Django ready in Jupyter

# %%
from tmdb import client as tmdb_client

# %%
response = tmdb_client.search_movie("Inception")
results = response.get("results")
for movie in results:
    print(f"{movie['title']} ({movie['release_date']})")
# Out:
# Inception (2010-07-15)
# The Crack: Inception (2019-10-04)
# Syndrome Halla, the Inception of Croatian Professional Film – Born to Die (2017-01-01)
# WWA The Inception (2001-10-26)
# Inception (1980-01-23)
# The Inception of Dramatic Representation ()
# The Inception of Seeking (2025-05-17)
# Bikini Inception (2015-05-19)
# Inception: The Cobol Job (2010-12-07)
# Inception: Music from the Motion Picture (2010-12-07)

# %%
response = tmdb_client.search_movie("Inception")
results = response.get("results")
movie_id = results[0]['id']
movie_id
# Out:
# 27205

# %%
response = tmdb_client.movies_details(movie_id)
response
# Out:
# {'adult': False,
#  'backdrop_path': '/ii8QGacT3MXESqBckQlyrATY0lT.jpg',
#  'belongs_to_collection': None,
#  'budget': 160000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.warnerbros.com/movies/inception',
#  'id': 27205,
#  'imdb_id': 'tt1375666',
#  'origin_country': ['US', 'GB'],
#  'original_language': 'en',
#  'original_title': 'Inception',
#  'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#  'popularity': 33.7271,
#  'poster_path': '/xlaY2zyzMfkhk0HSC5VUwzoZPU1.jpg',
#  'production_companies': [{'id': 923,
#    'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png',
#    'name': 'Legendary Pictures',
#    'origin_country': 'US'},
#   {'id': 9996,
#    'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png',
#    'name': 'Syncopy',
#    'origin_country': 'GB'},
#   {'id': 174,
#    'logo_path': '/ingPVoHnINIrFR7WHmYux1f5pES.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2010-07-15',
#  'revenue': 839030630,
#  'runtime': 148,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#   {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'},
#   {'english_name': 'Swahili', 'iso_639_1': 'sw', 'name': 'Kiswahili'}],
#  'status': 'Released',
#  'tagline': 'Your mind is the scene of the crime.',
#  'title': 'Inception',
#  'video': False,
#  'vote_average': 8.371,
#  'vote_count': 38408}

# %%
from ai.agents import get_document_agent
from langgraph.checkpoint.memory import InMemorySaver
import uuid

# %%
checkpointer = InMemorySaver()

# %%
agent = get_document_agent(
    model="gpt-4o-mini",
    checkpointer=checkpointer,
)

# %%
config = {
    "configurable": {
        "user_id": 7,
        "thread_id": str(uuid.uuid4())
    }
}

# %%
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Update the titlle too make it Stanger thing V"
            }
        ]
    },
    config=config,
)

# %%
from langchain_core.messages import AIMessage

final_answer = None

for msg in response["messages"]:
    if isinstance(msg, AIMessage) and msg.content:
        final_answer = msg.content

print(final_answer)
